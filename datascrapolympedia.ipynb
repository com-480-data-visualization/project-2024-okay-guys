# %% [markdown]
# ### Notebook run on colab for data scrapping the Olympedia Website : https://www.olympedia.org

# %% [markdown]
# This method was taken from Joseph Cheng : https://github.com/josephwccheng/olympedia_web_scraping/tree/main and slightly adapted to get the performance metrics when available.
# He considered it to be a futur step to do : "Download Raw HTML files of all the results from the "_distinct_result_id.csv" file. This is a todo for future work for those who would like to dive down more on each specific events and their performances"

# %%
# !pip install aiohttp nest_asyncio beautifulsoup4
# Out:
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (3.9.5)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp) (3.7)

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
from bs4 import BeautifulSoup
from typing import Dict, List, Tuple
import aiohttp
import asyncio
import nest_asyncio
import os
import time
import random

nest_asyncio.apply()

dataroot = os.path.join("/content", "drive", "MyDrive", "Colab files")
result_ids_path = os.path.join(dataroot, '_distinct_result_id.csv')
csv_save_path = os.path.join(dataroot, 'olympedia_all_results.csv')

# Function to identify if a row is part of the final round based on specific columns
def is_final_round(row, headers):
    final_columns = ["Final", "Final Round"]
    for col in final_columns:
        if col in headers and row.get(col, "").strip() and row.get(col).strip() != "–":
            return True
    return False

# Function to parse the event results and filter for final rounds
def parse_results_table(table) -> Tuple[List[str], List[Dict[str, str]]]:
    headers = [th.get_text().strip() for th in table.find_all('th')]
    rows = table.find_all('tr')[1:]  # skip the header row
    results = []

    has_final_column = any(col in headers for col in ["Final", "Final Round"])

    for row in rows:
        cols = row.find_all('td')
        if cols:
            result = {}
            for i, col in enumerate(cols):
                # Handle edge cases for cells containing spans or being empty
                if i < len(headers):
                    text = col.get_text().strip()
                    if not text:
                        text = "N/A"
                    result[headers[i]] = text
            if not has_final_column or is_final_round(result, headers):
                results.append(result)
    return headers, results

async def fetch(session, url, retries=5, backoff_factor=1):
    for attempt in range(retries):
        try:
            async with session.get(url) as response:
                if response.status == 200:
                    return await response.text()
                else:
                    raise ValueError(f"Request to {url} returned status {response.status}")
        except Exception as e:
            if attempt < retries - 1:
                sleep_time = backoff_factor * (2 ** attempt) + random.uniform(0, 1)
                print(f"Attempt {attempt + 1} failed: {e}. Retrying in {sleep_time:.2f} seconds...")
                await asyncio.sleep(sleep_time)
            else:
                print(f"All {retries} attempts failed for {url}.")
                raise e

async def fetch_result_page(session, result_id):
    base_url = 'https://www.olympedia.org'
    url = f"{base_url}/results/{result_id}"
    return await fetch(session, url)

async def scrape_result(result_id, semaphore):
    async with semaphore:
        async with aiohttp.ClientSession() as session:
            try:
                result_page = await fetch_result_page(session, result_id)
                return result_id, result_page
            except Exception as e:
                print(f"Error fetching result ID {result_id}: {e}")
                return result_id, None

def get_result_info_from_page(result_id: str, page_content: str) -> Dict:
    result_soup = BeautifulSoup(page_content, 'html.parser')
    try:
        breadcrumb = result_soup.select('body > div.container > ol.breadcrumb > li')
        edition = breadcrumb[2].get_text()
        edition_id = breadcrumb[2].find('a')['href'].split('/')[-1]
        sport = breadcrumb[3].get_text()
        event_title = result_soup.select('body > div.container > h1.event_title')[0].get_text()
    except IndexError as e:
        print(f"Error parsing breadcrumb or event title for result ID {result_id}: {e}")
        return {}

    event_info = {
        'result_id': result_id,
        'event_title': event_title,
        'edition': edition,
        'edition_id': edition_id,
        'sport': sport,
    }

    # Parsing the event bio table
    try:
        event_bio_table = result_soup.select('body > div.container > table.biodata')[0]
        event_bio_header = [item.get_text() for item in event_bio_table.select('table > tr > th')]
        event_bio_value = [item.get_text() for item in event_bio_table.select('table > tr > td')]

        bio_fields = {
            'Date': 'result_date',
            'Location': 'result_location',
            'Participants': 'result_participants',
            'Format': 'result_format'
        }

        for field, key in bio_fields.items():
            event_info[key] = event_bio_value[event_bio_header.index(field)] if field in event_bio_header else 'na'
    except (IndexError, AttributeError) as e:
        print(f"Error parsing event bio table for result ID {result_id}: {e}")
        for key in ['result_date', 'result_location', 'result_participants', 'result_format', 'result_detail']:
            event_info[key] = 'na'

    # Parsing the results table
    results_table = result_soup.find('table', class_='table table-striped')
    if results_table:
        try:
            headers, results = parse_results_table(results_table)
            event_info['results'] = results
        except Exception as e:
            print(f"Error parsing results table for result ID {result_id}: {e}")
            event_info['results'] = []
    else:
        event_info['results'] = []

    return event_info

def save_to_csv(all_results: List[Dict], all_columns: set, file_path: str):
    base_headers = [
        'result_id', 'event_title', 'edition', 'edition_id', 'sport',
        'result_date', 'result_location', 'result_participants',
        'result_format'
    ]
    result_headers = list(all_columns)
    headers = base_headers + result_headers

    with open(file_path, mode='w', newline='', encoding='utf-8') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=headers)
        writer.writeheader()

        for result_info in all_results:
            base_info = {k: result_info[k] for k in base_headers if k in result_info}
            for result in result_info['results']:
                row = {**base_info, **{col: '' for col in result_headers}, **result}
                writer.writerow(row)

async def main(result_ids):
    all_results = []
    all_columns = set()
    semaphore = asyncio.Semaphore(10) 

    tasks = [scrape_result(result_id, semaphore) for result_id in result_ids]

    for i, task in enumerate(asyncio.as_completed(tasks)):
        result_id, result_page = await task
        if result_page:
            result_info = get_result_info_from_page(result_id, result_page)
            if result_info:  
                all_results.append(result_info)
                for result in result_info['results']:
                    all_columns.update(result.keys())

    save_to_csv(all_results, all_columns, csv_save_path)
    print("Combined CSV file has been saved.")

def load_result_ids(file_path: str) -> List[str]:
    with open(file_path, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        result_ids = [row[0] for row in reader]
    return result_ids

# Run the script
if __name__ == "__main__":
    result_ids = load_result_ids(result_ids_path)
    asyncio.run(main(result_ids))
# Out:
# Attempt 1 failed: Request to https://www.olympedia.org/results/45335 returned status 504. Retrying in 1.68 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/85903 returned status 504. Retrying in 1.41 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/354150 returned status 504. Retrying in 1.52 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/34161 returned status 504. Retrying in 1.65 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/111376 returned status 504. Retrying in 1.99 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/34161 returned status 504. Retrying in 2.95 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/27375 returned status 504. Retrying in 1.55 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/111376 returned status 504. Retrying in 2.82 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/260363 returned status 504. Retrying in 1.70 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/354218 returned status 504. Retrying in 1.67 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/22214 returned status 504. Retrying in 1.26 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/354218 returned status 504. Retrying in 2.42 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/22214 returned status 504. Retrying in 2.20 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/22214 returned status 500. Retrying in 4.97 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/354218 returned status 504. Retrying in 4.72 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/262828 returned status 504. Retrying in 1.64 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/22214 returned status 504. Retrying in 8.45 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/395646 returned status 504. Retrying in 1.54 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/395646 returned status 504. Retrying in 2.67 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/306000 returned status 504. Retrying in 1.45 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/47135 returned status 504. Retrying in 1.44 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/154371 returned status 504. Retrying in 1.06 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/47135 returned status 504. Retrying in 2.13 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/47491 returned status 504. Retrying in 1.81 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/47135 returned status 504. Retrying in 4.14 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/47491 returned status 504. Retrying in 2.46 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/301118 returned status 504. Retrying in 1.85 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/261879 returned status 504. Retrying in 1.55 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/301118 returned status 504. Retrying in 2.25 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/261879 returned status 504. Retrying in 2.30 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/154333 returned status 504. Retrying in 1.14 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/154333 returned status 504. Retrying in 2.41 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/159234 returned status 504. Retrying in 1.03 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/154333 returned status 504. Retrying in 4.94 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/261076 returned status 504. Retrying in 1.37 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/159234 returned status 504. Retrying in 2.70 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/154333 returned status 504. Retrying in 8.73 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/48003 returned status 504. Retrying in 1.23 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/86675 returned status 504. Retrying in 1.81 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/86675 returned status 504. Retrying in 2.69 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/16121 returned status 504. Retrying in 1.47 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/16121 returned status 500. Retrying in 2.88 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/97028 returned status 504. Retrying in 1.88 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/306066 returned status 504. Retrying in 1.45 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/18000588 returned status 504. Retrying in 1.68 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/33975 returned status 504. Retrying in 1.45 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/306066 returned status 504. Retrying in 2.38 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/258609 returned status 504. Retrying in 1.71 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/45037 returned status 504. Retrying in 1.01 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/18000588 returned status 504. Retrying in 2.02 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/306066 returned status 504. Retrying in 4.48 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/258609 returned status 504. Retrying in 2.58 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/18000588 returned status 504. Retrying in 4.30 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/306066 returned status 504. Retrying in 8.83 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/258609 returned status 504. Retrying in 4.36 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/48552 returned status 504. Retrying in 1.73 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/154922 returned status 504. Retrying in 1.35 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/48552 returned status 504. Retrying in 2.89 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/154922 returned status 504. Retrying in 2.31 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/18000470 returned status 504. Retrying in 1.40 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/19001150 returned status 504. Retrying in 1.37 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/48552 returned status 504. Retrying in 4.87 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/154922 returned status 504. Retrying in 4.76 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/61029 returned status 504. Retrying in 1.11 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/19001150 returned status 504. Retrying in 2.62 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/56290 returned status 504. Retrying in 1.90 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/48552 returned status 504. Retrying in 8.16 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/304111 returned status 504. Retrying in 1.36 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/350234 returned status 504. Retrying in 1.80 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/37341 returned status 504. Retrying in 1.55 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/19005318 returned status 504. Retrying in 1.12 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/63701 returned status 504. Retrying in 1.97 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/314051 returned status 504. Retrying in 1.50 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/19000663 returned status 504. Retrying in 1.12 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/314051 returned status 504. Retrying in 2.01 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/314051 returned status 504. Retrying in 4.21 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/104965 returned status 504. Retrying in 1.26 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/314051 returned status 504. Retrying in 8.89 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/14019 returned status 504. Retrying in 1.64 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/70048 returned status 500. Retrying in 1.55 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/60093 returned status 504. Retrying in 1.22 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/19016400 returned status 504. Retrying in 1.65 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/357350 returned status 504. Retrying in 1.27 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/9000930 returned status 504. Retrying in 1.94 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/result_id returned status 404. Retrying in 1.15 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/result_id returned status 404. Retrying in 2.21 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/result_id returned status 404. Retrying in 4.96 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/result_id returned status 404. Retrying in 8.84 seconds...
# All 5 attempts failed for https://www.olympedia.org/results/result_id.
# Error fetching result ID result_id: Request to https://www.olympedia.org/results/result_id returned status 404
# Attempt 1 failed: Request to https://www.olympedia.org/results/47784 returned status 504. Retrying in 1.69 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/920003 returned status 500. Retrying in 1.54 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results
seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/108488 returned status 504. Retrying in 4.60 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/72859 returned status 504. Retrying in 1.01 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/153772 returned status 504. Retrying in 1.99 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/324142 returned status 504. Retrying in 1.96 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/72859 returned status 504. Retrying in 2.70 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/19001710 returned status 504. Retrying in 1.22 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/19001710 returned status 504. Retrying in 2.55 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/19001710 returned status 504. Retrying in 4.76 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/19012000 returned status 504. Retrying in 1.03 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/19001710 returned status 504. Retrying in 8.39 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/40499 returned status 404. Retrying in 1.99 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/40499 returned status 404. Retrying in 2.23 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/40499 returned status 404. Retrying in 4.72 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/40499 returned status 404. Retrying in 8.25 seconds...
# All 5 attempts failed for https://www.olympedia.org/results/40499.
# Error fetching result ID 40499: Request to https://www.olympedia.org/results/40499 returned status 404
# Attempt 1 failed: Request to https://www.olympedia.org/results/90541 returned status 504. Retrying in 1.15 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/90541 returned status 504. Retrying in 2.93 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/44325 returned status 500. Retrying in 1.39 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/31058 returned status 504. Retrying in 1.94 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/26012 returned status 500. Retrying in 1.10 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/45876 returned status 504. Retrying in 1.74 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/19020120 returned status 504. Retrying in 1.21 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/159765 returned status 500. Retrying in 1.98 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/42107 returned status 504. Retrying in 1.66 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/31058 returned status 504. Retrying in 2.61 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/45876 returned status 504. Retrying in 2.80 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/19020120 returned status 504. Retrying in 2.19 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/42107 returned status 504. Retrying in 2.64 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/31058 returned status 504. Retrying in 4.25 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/9000850 returned status 504. Retrying in 1.51 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/255809 returned status 504. Retrying in 1.06 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/35685 returned status 500. Retrying in 1.42 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/45876 returned status 504. Retrying in 4.04 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/19020120 returned status 504. Retrying in 4.99 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/42107 returned status 504. Retrying in 4.12 seconds...
# Attempt 4 failed: Request to https://www.olympedia.org/results/31058 returned status 504. Retrying in 8.96 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/9000850 returned status 504. Retrying in 2.55 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/45440 returned status 504. Retrying in 1.18 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/924415 returned status 504. Retrying in 1.68 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/47711 returned status 504. Retrying in 1.11 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/109473 returned status 504. Retrying in 1.29 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/94245 returned status 504. Retrying in 1.17 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/47711 returned status 504. Retrying in 2.62 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/109473 returned status 504. Retrying in 2.77 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/94245 returned status 504. Retrying in 2.25 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/47711 returned status 504. Retrying in 4.17 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/31149 returned status 504. Retrying in 1.12 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/129931 returned status 504. Retrying in 1.62 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/31149 returned status 504. Retrying in 2.65 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/31149 returned status 504. Retrying in 4.66 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/96118 returned status 504. Retrying in 1.55 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/107851 returned status 504. Retrying in 1.53 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/96118 returned status 504. Retrying in 2.70 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/42000 returned status 504. Retrying in 1.54 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/107851 returned status 504. Retrying in 2.63 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/96118 returned status 504. Retrying in 4.83 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/44578 returned status 504. Retrying in 1.71 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/42000 returned status 504. Retrying in 2.08 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/31258 returned status 504. Retrying in 1.45 seconds...
# Attempt 2 failed: Request to https://www.olympedia.org/results/31258 returned status 504. Retrying in 2.17 seconds...
# Attempt 3 failed: Request to https://www.olympedia.org/results/31258 returned status 504. Retrying in 4.90 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/48121 returned status 504. Retrying in 1.29 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/77461 returned status 504. Retrying in 1.93 seconds...
# Attempt 1 failed: Request to https://www.olympedia.org/results/92978 returned status 504. Retrying in 1.60 seconds...
# Combined CSV file has been saved.
